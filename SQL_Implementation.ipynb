# %%
# --- SETUP & LOAD DATA ---

import pandas as pd
import sqlite3

file_name = 'Analisis Keterlambatan & Akurasi Waktu (Final).xlsx'
try:
    df = pd.read_excel(file_name)
    # Clean column names
    df.columns = [c.strip().replace(' ', '_').replace('.', '').replace('(', '').replace(')', '').replace('/', '_per_').lower() for c in df.columns]
    
    # Setup SQL Memory
    conn = sqlite3.connect(':memory:')
    df.to_sql('pizza_sales', conn, index=False, if_exists='replace')
    print("✅ Database Loaded Successfully\n")
except Exception as e:
    print(f"Error: {e}")
# Out:
# ✅ Database Loaded Successfully

# %%
# --- EFFICIENCY ANALYSIS ---

query_efficiency = """
SELECT 
    restaurant_name,
    AVG(dist_km) as avg_distance_km,
    AVG(delivery_duration_min) as avg_duration,
    ROUND(SUM(delivery_duration_min) / SUM(dist_km), 2) as avg_efficiency_min_per_km,
    SUM(CASE WHEN is_delayed = 'Yes' THEN 1 ELSE 0 END) as total_late_orders
FROM 
    pizza_sales
GROUP BY 
    restaurant_name
HAVING 
    COUNT(order_id) > 5
ORDER BY 
    avg_efficiency_min_per_km ASC;
"""

print("--- EFISIENSI RESTORAN ---")
display(pd.read_sql_query(query_efficiency, conn))
# Out:
# --- EFISIENSI RESTORAN ---
#   restaurant_name  avg_distance_km  avg_duration  avg_efficiency_min_per_km  \
# 0        Domino's         5.750000     30.259434                        5.0
# 1  Little Caesars         5.271357     28.844221                        5.0
# 2   Marco's Pizza         5.189744     30.230769                        5.0
# 3       Pizza Hut         5.000000     29.948454                        5.0
# 4     Papa John's         4.387255     28.186275                        6.0
#
#    total_late_orders
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
# --- PRODUCT COMPLEXITY ANALYSIS ---

query_complexity = """
SELECT 
    pizza_complexity,
    pizza_size,
    COUNT(order_id) as total_orders,
    ROUND(AVG(toppings_count), 1) as avg_toppings,
    ROUND(AVG(delivery_duration_min), 1) as avg_delivery_time,
    ROUND(
        (SUM(CASE WHEN is_delayed = 'Yes' THEN 1 ELSE 0 END) * 100.0) / COUNT(order_id), 
        1
    ) as late_percentage
FROM 
    pizza_sales
GROUP BY 
    pizza_complexity, pizza_size
ORDER BY 
    late_percentage DESC;
"""

print("\n--- DAMPAK KOMPLEKSITAS PIZZA ---")
display(pd.read_sql_query(query_complexity, conn))
# Out:
# --- DAMPAK KOMPLEKSITAS PIZZA ---
#     pizza_complexity pizza_size  total_orders  avg_toppings  \
# 0                  1      Small            43           1.0
# 1                  2      Small            87           2.0
# 2                  3      Small             2           3.0
# 3                  4     Medium           110           2.0
# 4                  6     Medium           308           3.0
# 5                  8     Medium            11           4.0
# 6                  8         XL             1           2.0
# 7                  9      Large             9           3.0
# 8                 12      Large           229           4.0
# 9                 15      Large             2           5.0
# 10                20         XL           202           5.0
#
#     avg_delivery_time  late_percentage
# 0                20.2              0.0
# 1                22.5              0.0
# 2                27.5              0.0
# 3                26.3              0.0
# 4                28.0              0.0
# 5                27.7              0.0
# 6                45.0              0.0
# 7                28.3              0.0
# 8                34.3              0.0
# 9                40.0              0.0
# 10               33.0              0.0

# %%
# --- OPERATIONAL BOTTLENECKS ---
query_window = """
SELECT 
    restaurant_name,
    order_id,
    delivery_duration_min,
    traffic_level,
    pizza_complexity,
    (delivery_duration_min - 30) as excess_time_minutes
FROM (
    SELECT 
        *,
        RANK() OVER (PARTITION BY restaurant_name ORDER BY delivery_duration_min DESC) as rank_lambat
    FROM 
        pizza_sales
) ranked_table 
WHERE 
    rank_lambat = 1
ORDER BY 
    delivery_duration_min DESC;
"""
print("\n--- OPERATIONAL BOTTLENECKS ---")
display(pd.read_sql_query(query_window, conn))
# Out:
# --- OPERATIONAL BOTTLENECKS ---
#    restaurant_name order_id  delivery_duration_min traffic_level  \
# 0         Domino's   ORD465                     50          High
# 1         Domino's   ORD475                     50          High
# 2         Domino's   ORD485                     50          High
# 3         Domino's   ORD493                     50          High
# 4         Domino's   ORD503                     50          High
# 5         Domino's   ORD513                     50          High
# 6         Domino's   ORD521                     50          High
# 7         Domino's   ORD531                     50          High
# 8         Domino's   ORD541                     50          High
# 9         Domino's   ORD554                     50          High
# 10        Domino's   ORD564                     50          High
# 11        Domino's   ORD581                     50          High
# 12        Domino's   ORD591                     50          High
# 13        Domino's   ORD611                     50          High
# 14        Domino's   ORD621                     50          High
# 15        Domino's   ORD646                     50          High
# 16  Little Caesars   ORD627                     50          High
# 17   Marco's Pizza   ORD130                     50          High
# 18   Marco's Pizza   ORD140                     50          High
# 19   Marco's Pizza   ORD150                     50          High
# 20   Marco's Pizza   ORD271                     50          High
# 21   Marco's Pizza   ORD311                     50          High
# 22   Marco's Pizza   ORD321                     50          High
# 23   Marco's Pizza   ORD331                     50          High
# 24   Marco's Pizza   ORD336                     50          High
# 25   Marco's Pizza   ORD341                     50          High
# 26   Marco's Pizza   ORD351                     50          High
# 27   Marco's Pizza   ORD361                     50          High
# 28   Marco's Pizza   ORD367                     50          High
# 29   Marco's Pizza   ORD377                     50          High
# 30   Marco's Pizza   ORD387                     50          High
# 31   Marco's Pizza   ORD393                     50          High
# 32   Marco's Pizza   ORD403                     50          High
# 33   Marco's Pizza   ORD413                     50          High
# 34   Marco's Pizza   ORD419                     50          High
# 35   Marco's Pizza   ORD429                     50          High
# 36   Marco's Pizza   ORD439                     50          High
# 37   Marco's Pizza   ORD449                     50          High
# 38     Papa John's   ORD637                     50          High
# 39       Pizza Hut   ORD457                     50          High
#
#     pizza_complexity  excess_time_minutes
# 0                 12                   20
# 1                 12                   20
# 2                 12                   20
# 3                 12                   20
# 4                 12                   20
# 5                 12                   20
# 6                 12                   20
# 7                 12                   20
# 8                 12                   20
# 9                 12                   20
# 10                12                   20
# 11                12                   20
# 12                12                   20
# 13                12                   20
# 14                12                   20
# 15                12                   20
# 16                20                   20
# 17                12                   20
# 18                12                   20
# 19                12                   20
# 20                12                   20
# 21                12                   20
# 22                12                   20
# 23                12                   20
# 24                12                   20
# 25                12                   20
# 26                12                   20
# 27                12                   20
# 28                12                   20
# 29                12                   20
# 30                12                   20
# 31                12                   20
# 32                12                   20
# 33                12                   20
# 34                12                   20
# 35                12                   20
# 36                12                   20
# 37                12                   20
# 38                12                   20
# 39                12                   20
